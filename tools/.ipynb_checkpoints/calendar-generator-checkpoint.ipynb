# %%
import pandas as pd
import datetime

start = datetime.datetime(2020, 1, 21)
print("start: " + str(start.date()) + " (" + start.strftime("%a") + ")")
end = datetime.datetime(2020, 5, 15)
print("end: " + str(end.date()) + " (" + end.strftime("%a") + ")")

while start.weekday() != 0:
    start += datetime.timedelta(-1)
print("extended start: " + str(start.date()) + " (" + start.strftime("%a") + ")")
while end.weekday() != 4:
    end += datetime.timedelta(1)
print("extended end: " + str(end.date()) + " (" + end.strftime("%a") + ")")
# Out:
# start: 2020-01-21 (Tue)
# end: 2020-05-15 (Fri)
# extended start: 2020-01-20 (Mon)
# extended end: 2020-05-15 (Fri)

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %%
dtrange = pd.date_range(start = start, end = end, freq = 'B')

cal = pd.DataFrame(dtrange)

cal.insert(1, 'month', dtrange.strftime("%B"))
cal.insert(2, 'day', dtrange.strftime("%a"))

week = []
for i in range(0,cal.shape[0]):
    week.append(int(i/5)+1)

cal.insert(3, 'week', pd.Series(week))

l = []
for week in range(1, cal['week'].nunique()+1):
    l.append(cal[cal['week'] == week]['month'].mode()[0])
    
block = []
for week in cal['week']:
    block.append(l[week-1])

cal.insert(4, 'block', pd.Series(block))

print(cal.shape)
print_full(cal)
# Out:
# (85, 5)
#             0     month  day  week     block
# 0  2020-01-20   January  Mon     1   January
# 1  2020-01-21   January  Tue     1   January
# 2  2020-01-22   January  Wed     1   January
# 3  2020-01-23   January  Thu     1   January
# 4  2020-01-24   January  Fri     1   January
# 5  2020-01-27   January  Mon     2   January
# 6  2020-01-28   January  Tue     2   January
# 7  2020-01-29   January  Wed     2   January
# 8  2020-01-30   January  Thu     2   January
# 9  2020-01-31   January  Fri     2   January
# 10 2020-02-03  February  Mon     3  February
# 11 2020-02-04  February  Tue     3  February
# 12 2020-02-05  February  Wed     3  February
# 13 2020-02-06  February  Thu     3  February
# 14 2020-02-07  February  Fri     3  February
# 15 2020-02-10  February  Mon     4  February
# 16 2020-02-11  February  Tue     4  February
# 17 2020-02-12  February  Wed     4  February
# 18 2020-02-13  February  Thu     4  February
# 19 2020-02-14  February  Fri     4  February
# 20 2020-02-17  February  Mon     5  February
# 21 2020-02-18  February  Tue     5  February
# 22 2020-02-19  February  Wed     5  February
# 23 2020-02-20  February  Thu     5  February
# 24 2020-02-21  February  Fri     5  February
# 25 2020-02-24  February  Mon     6  February
# 26 2020-02-25  February  Tue     6  February
# 27 2020-02-26  February  Wed     6  February
# 28 2020-02-27  February  Thu     6  February
# 29 2020-02-28  February  Fri     6  February
# 30 2020-03-02     March  Mon     7     March
# 31 2020-03-03     March  Tue     7     March
# 32 2020-03-04     March  Wed     7     March
# 33 2020-03-05     March  Thu     7     March
# 34 2020-03-06     March  Fri     7     March
# 35 2020-03-09     March  Mon     8     March
# 36 2020-03-10     March  Tue     8     March
# 37 2020-03-11     March  Wed     8     March
# 38 2020-03-12     March  Thu     8     March
# 39 2020-03-13     March  Fri     8     March
# 40 2020-03-16     March  Mon     9     March
# 41 2020-03-17     March  Tue     9     March
# 42 2020-03-18     March  Wed     9     March
# 43 2020-03-19     March  Thu     9     March
# 44 2020-03-20     March  Fri     9     March
# 45 2020-03-23     March  Mon    10     March
# 46 2020-03-24     March  Tue    10     March
# 47 2020-03-25     March  Wed    10     March
# 48 2020-03-26     March  Thu    10     March
# 49 2020-03-27     March  Fri    10     March
# 50 2020-03-30     March  Mon    11     April
# 51 2020-03-31     March  Tue    11     April
# 52 2020-04-01     April  Wed    11     April
# 53 2020-04-02     April  Thu    11     April
# 54 2020-04-03     April  Fri    11     April
# 55 2020-04-06     April  Mon    12     April
# 56 2020-04-07     April  Tue    12     April
# 57 2020-04-08     April  Wed    12     April
# 58 2020-04-09     April  Thu    12     April
# 59 2020-04-10     April  Fri    12     April
# 60 2020-04-13     April  Mon    13     April
# 61 2020-04-14     April  Tue    13     April
# 62 2020-04-15     April  Wed    13     April
# 63 2020-04-16     April  Thu    13     April
# 64 2020-04-17     April  Fri    13     April
# 65 2020-04-20     April  Mon    14     April
# 66 2020-04-21     April  Tue    14     April
# 67 2020-04-22     April  Wed    14     April
# 68 2020-04-23     April  Thu    14     April
# 69 2020-04-24     April  Fri    14     April
# 70 2020-04-27     April  Mon    15     April
# 71 2020-04-28     April  Tue    15     April
# 72 2020-04-29     April  Wed    15     April
# 73 2020-04-30     April  Thu    15     April
# 74 2020-05-01       May  Fri    15     April
# 75 2020-05-04       May  Mon    16       May
# 76 2020-05-05       May  Tue    16       May
# 77 2020-05-06       May  Wed    16       May
# 78 2020-05-07       May  Thu    16       May
# 79 2020-05-08       May  Fri    16       May
# 80 2020-05-11       May  Mon    17       May
# 81 2020-05-12       May  Tue    17       May
# 82 2020-05-13       May  Wed    17       May
# 83 2020-05-14       May  Thu    17       May
# 84 2020-05-15       May  Fri    17       May

# %%
week_topics = {
    1: "<b>Week 1: Chapter 1</b><br>(Controlled Experiments)",
    2: "<b>Week 2: Chapters 2-3</b><br>(Observational Studies)",
    3: "<b>Week 3: Chapters 3-5</b><br>(Histograms, Avg, Median, SD, & Normal Curve)",
    4: "<b>Week 4: Exam Week</b>",
    5: "<b>Week 5: Chapters 6-7</b><br>(Boxplots & Correlation)",
    6: "<b>Week 6: Chapters 8-10</b><br>(Regression & RMSE)",
    7: "<b>Week 7: Chapters 11-12</b><br>(Probability)",
    8: "<b>Week 8: Exam Week</b>",
    9: "<b>Week 9: Spring Break</b>",
    10: "<b>Week 10: Chapters 13-15</b><br>(EV, SE, & Random Variables)",
    11: "<b>Week 11: Chapters 15-16</b><br>(Box Models & Probability Histograms)",
    12: "<b>Week 12: Exam Week</b>",
    13: "<b>Week 13: Chapters 17-19</b><br>(Sampling & Inference)",
    14: "<b>Week 14: Chapters 20-22</b><br>(Hypothesis Testing: Z & t Tests)",
    15: "<b>Week 15: Chapters 22-24</b><br>(Hypothesis Testing: Chi Square Tests)",
    16: "<b>Week 16: Last Week of Class</b><br>(Final Exam Review)",
    17: "<b>Week 17: Finals Week</b>"
}

prelectures = {
    '2020-01-25': 'Chapter 1 Prelecture Due',
    '2020-01-29': 'Chapter 2 Part 1 Prelecture Due',
    '2020-01-31': 'Chapter 2 Part 2 Prelecture Due',
    '2020-02-03': 'Chapter 3 Prelecture Due',
    '2020-02-05': 'Chapter 4 Prelecture Due',
    '2020-02-07': 'Chapter 5 Prelecture Due',
    '2020-02-19': 'Chapter 7 Prelecture Due',
    '2020-02-26': 'Chapter 8 Prelecture Due',
    '2020-02-28': 'Chapter 9 Prelecture Due',
    '2020-03-02': 'Chapter 10 Prelecture Due',
    '2020-03-04': 'Chapter 11 Prelecture Due',
    '2020-03-09': 'Chapter 12 Prelecture Due',
    '2020-03-25': 'Chapter 13 Prelecture Due',
    '2020-03-27': 'Chapter 14 Prelecture Due',
    '2020-04-01': 'Chapter 15 Prelecture Due',
    '2020-04-03': 'Chapter 16 Prelecture Due',
    '2020-04-08': 'Chapter 17 Prelecture Due',
    '2020-04-10': 'Chapter 18 Prelecture Due',
    '2020-04-22': 'Chapter 20 Prelecture Due',
    '2020-04-24': 'Chapter 21 Prelecture Due',
    '2020-04-29': 'Chapter 22 Prelecture Due',
    '2020-05-01': 'Chapter 23 Part 1 Prelecture Due',
    '2020-05-05': 'Chapter 23 Part 2 Prelecture Due'
}
surveys = {
    '2020-01-25': 'Bonus Survey 1 Due',
    '2020-02-07': 'Bonus Survey 2 Due',
    '2020-02-28': 'Bonus Survey 3 Due',
    '2020-04-03': 'Bonus Survey 4 Due',
    '2020-05-06': 'Bonus Survey 5 Due'
}
homeworks = {
    '2020-01-29': 'HW Assignment 1 Due',
    '2020-01-31': 'HW Assignment 2 Due',
    '2020-02-04': 'HW Assignment 3 Due',
    '2020-02-06': 'HW Assignment 4 Due',
    '2020-02-11': 'HW Assignment 5 Due',
    '2020-02-20': 'HW Assignment 6 Due',
    '2020-02-25': 'HW Assignment 7 Due',
    '2020-02-27': 'HW Assignment 8 Due',
    '2020-03-03': 'HW Assignment 9 Due',
    '2020-03-05': 'HW Assignment 10 Due',
    '2020-03-10': 'HW Assignment 11 Due',
    '2020-03-26': 'HW Assignment 12 Due',
    '2020-03-31': 'HW Assignment 13 Due',
    '2020-04-02': 'HW Assignment 14 Due',
    '2020-04-07': 'HW Assignment 15 Due',
    '2020-04-09': 'HW Assignment 16 Due',
    '2020-04-14': 'HW Assignment 17 Due',
    '2020-04-23': 'HW Assignment 18 Due',
    '2020-04-28': 'HW Assignment 19 Due',
    '2020-04-30': 'HW Assignment 20 Due',
    '2020-05-06': 'HW Assignment 21 Due'
}
general = {
    '2020-01-20': 'Martin Luther King Jr. Day',
    '2020-01-21': 'First Day of Classes!',
    '2020-02-13': 'No Class :)',
    '2020-02-14': "Valentine's Day",
    '2020-02-17': "President's Day",
    '2020-03-16': '---',
    '2020-03-17': '---',
    '2020-03-18': 'SPRING BREAK',
    '2020-03-19': '---',
    '2020-03-20': '---',
    '2020-05-07': '<b>Reading Day</b><br>No Class :)',
    '2020-05-08': 'No Class :)',
    '2020-05-15': '<b>SUMMER BREAK!!!</b><br><br>Have a wonderful break!'
}
conflicts = {
    '2020-02-07': 'Exam 1 Conflict Sign-Up Due',
    '2020-03-06': 'Exam 2 Conflict Sign-Up Due',
    '2020-04-03': 'Exam 3 Conflict Sign-Up Due'
}
exams = {
    '2020-02-12': 'Exam 1 at 7pm',
    '2020-03-11': 'Exam 2 at 7pm',
    '2020-04-08': 'Exam 3 at 7pm',
    '2020-05-11': 'L1 (In Person Class) Final from 1:30pm-4:30pm',
    '2020-05-12': "KF: (Karle's Online Class) Final from: 8am-11am",
    '2020-05-14': "ONL (Albert's Online Class) Final from: 7pm-10pm"
}

# %%
# 6 categories to check
# Priority levels:
#     1. Exams
#     2. Conflicts
#     3. Homeworks
#     4. Prelectures
#     5. Surveys
#     6. General
doc = ''
doc += '<style>th {\nwidth=16.66%;height:30;text-align:center;}td{text-align:center;font-size:65%;padding:0;margin:0;}table{table-layout:fixed;margin:0;padding:0;}</style>\n'
doc += '<div class="table-responsive">\n'
head = ('<tr>\n'+
        '  <th>Week</th>\n'+
        '  <th>Mon</th>\n'+
        '  <th>Tues</th>\n'+
        '  <th>Wed</th>\n'+
        '  <th>Thurs</th>\n'+
        '  <th>Fri</th>\n'+
        '</tr>')

for block in cal['block'].value_counts()[cal['block'].unique()].index.tolist():
#     print('<h1>' + block + '</h1>')
    doc += '<h3 style="text-align: center;">' + block + '</h3>'
    doc += '\n<div class="heading-underline"></div>'
    doc +=  '\n<table class="table table-bordered">'
#     print(head)
    doc += '\n' + head + '\n'
    sub1 = cal[cal['block'] == block]
    for week in sub1['week'].value_counts()[sub1['week'].unique()].index.tolist():
        sub2 = sub1[sub1['week'] == week]
        date = ''
        content = ''
        date += '<tr>\n  <td style="line-height:1px;margin:0;"></td>'
        content += '\n<tr>' + '\n  <td>' + str(week_topics.get(week)) + '</td>'
        for day in sub2[0]:
            events = []
            date += '\n  <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">' + str(day.strftime("%d")) + '</p></td>'
            if (exams.get(str(day.date())) != None):
                events.append('<b><p style="color:red;font-size:120%;">' + exams.get(str(day.date())) + '</p></b>')
            if (conflicts.get(str(day.date())) != None):
                events.append('<b><p style="font-size:120%;">' + conflicts.get(str(day.date())) + '</p></b>')
            if (homeworks.get(str(day.date())) != None):
                events.append('<p style="color:red;font-size:100%;">' + homeworks.get(str(day.date())) + '</p>')
            if (prelectures.get(str(day.date())) != None):
                events.append('<p style="color:blue;font-size:100%;">' + prelectures.get(str(day.date())) + '</p>')
            if (surveys.get(str(day.date())) != None):
                events.append('<p style="color:blue;font-size:100%;">' + surveys.get(str(day.date())) + '</p>')
            if (general.get(str(day.date())) != None):
                events.append('<p>' + general.get(str(day.date())) + '</p>')
            if len(events) > 1:
                content += '\n  <td>'
                n=0
                for event in events:
                    n += 1
                    if n == len(events):
                        content += event
                    else:
                        content += event + '<br>'
                content += '</td>'
            elif len(events) == 1:
                content += '\n  <td>' + events[0] + '</td>'
            elif len(events) == 0:
                content += '\n  <td></td>'
        content += '\n</tr>'
        date += '\n</tr>'
        doc += date + content
        doc += '\n'
#         print(date, content)
#     print('\n')
    doc += '</table>\n\n'
doc += '</div>'
print(doc)
# Out:
# <style> th {width=16.66%;height:30;text-align:center;}
# td {text-align:center}</style>
# <div class="table-responsive">
# <h3 style="text-align: center;">January</h3>
# <div class="heading-underline"></div>
# <table class="table table-bordered">
# <tr>
#   <th>Week</th>
#   <th>Mon</th>
#   <th>Tues</th>
#   <th>Wed</th>
#   <th>Thurs</th>
#   <th>Fri</th>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">20</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">21</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">22</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">23</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">24</p></td>
# </tr>
# <tr>
#   <td><b>Week 1: Chapter 1</b><br>(Controlled Experiments)</td>
#   <td><p>Martin Luther King Jr. Day</p></td>
#   <td><p>First Day of Classes!</p></td>
#   <td></td>
#   <td></td>
#   <td></td>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">27</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">28</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">29</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">30</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">31</p></td>
# </tr>
# <tr>
#   <td><b>Week 2: Chapters 2-3</b><br>(Observational Studies)</td>
#   <td></td>
#   <td></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 1 Due</p><br><p style="color:blue;font-size:100%;">Chapter 2 Part 1 Prelecture Due</p></td>
#   <td></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 2 Due</p><br><p style="color:blue;font-size:100%;">Chapter 2 Part 2 Prelecture Due</p></td>
# </tr>
# </table>
#
# <h3 style="text-align: center;">February</h3>
# <div class="heading-underline"></div>
# <table class="table table-bordered">
# <tr>
#   <th>Week</th>
#   <th>Mon</th>
#   <th>Tues</th>
#   <th>Wed</th>
#   <th>Thurs</th>
#   <th>Fri</th>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">03</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">04</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">05</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">06</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">07</p></td>
# </tr>
# <tr>
#   <td><b>Week 3: Chapters 3-5</b><br>(Histograms, Avg, Median, SD, & Normal Curve)</td>
#   <td><p style="color:blue;font-size:100%;">Chapter 3 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 3 Due</p></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 4 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 4 Due</p></td>
#   <td><b><p style="font-size:120%;">Exam 1 Conflict Sign-Up Due</p></b><br><p style="color:blue;font-size:100%;">Chapter 5 Prelecture Due</p><br><p style="color:blue;font-size:100%;">Bonus Survey 2 Due</p></td>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">10</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">11</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">12</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">13</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">14</p></td>
# </tr>
# <tr>
#   <td><b>Week 4: Exam Week</b></td>
#   <td></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 5 Due</p></td>
#   <td><b><p style="color:red;font-size:120%;">Exam 1 at 7pm</p></b></td>
#   <td><p>No Class :)</p></td>
#   <td><p>Valentine's Day</p></td>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">17</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">18</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">19</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">20</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">21</p></td>
# </tr>
# <tr>
#   <td><b>Week 5: Chapters 6-7</b><br>(Boxplots & Correlation)</td>
#   <td><p>President's Day</p></td>
#   <td></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 7 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 6 Due</p></td>
#   <td></td>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">24</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">25</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">26</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">27</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">28</p></td>
# </tr>
# <tr>
#   <td><b>Week 6: Chapters 8-10</b><br>(Regression & RMSE)</td>
#   <td></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 7 Due</p></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 8 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 8 Due</p></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 9 Prelecture Due</p><br><p style="color:blue;font-size:100%;">Bonus Survey 3 Due</p></td>
# </tr>
# </table>
#
# <h3 style="text-align: center;">March</h3>
# <div class="heading-underline"></div>
# <table class="table table-bordered">
# <tr>
#   <th>Week</th>
#   <th>Mon</th>
#   <th>Tues</th>
#   <th>Wed</th>
#   <th>Thurs</th>
#   <th>Fri</th>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">02</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">03</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">04</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">05</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">06</p></td>
# </tr>
# <tr>
#   <td><b>Week 7: Chapters 11-12</b><br>(Probability)</td>
#   <td><p style="color:blue;font-size:100%;">Chapter 10 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 9 Due</p></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 11 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 10 Due</p></td>
#   <td><b><p style="font-size:120%;">Exam 2 Conflict Sign-Up Due</p></b></td>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">09</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">10</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">11</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">12</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">13</p></td>
# </tr>
# <tr>
#   <td><b>Week 8: Exam Week</b></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 12 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 11 Due</p></td>
#   <td><b><p style="color:red;font-size:120%;">Exam 2 at 7pm</p></b></td>
#   <td></td>
#   <td></td>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">16</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">17</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">18</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">19</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">20</p></td>
# </tr>
# <tr>
#   <td><b>Week 9: Spring Break</b></td>
#   <td><p>---</p></td>
#   <td><p>---</p></td>
#   <td><p>SPRING BREAK</p></td>
#   <td><p>---</p></td>
#   <td><p>---</p></td>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">23</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">24</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">25</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">26</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">27</p></td>
# </tr>
# <tr>
#   <td><b>Week 10: Chapters 13-15</b><br>(EV, SE, & Random Variables)</td>
#   <td></td>
#   <td></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 13 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 12 Due</p></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 14 Prelecture Due</p></td>
# </tr>
# </table>
#
# <h3 style="text-align: center;">April</h3>
# <div class="heading-underline"></div>
# <table class="table table-bordered">
# <tr>
#   <th>Week</th>
#   <th>Mon</th>
#   <th>Tues</th>
#   <th>Wed</th>
#   <th>Thurs</th>
#   <th>Fri</th>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">30</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">31</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">01</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">02</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">03</p></td>
# </tr>
# <tr>
#   <td><b>Week 11: Chapters 15-16</b><br>(Box Models & Probability Histograms)</td>
#   <td></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 13 Due</p></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 15 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 14 Due</p></td>
#   <td><b><p style="font-size:120%;">Exam 3 Conflict Sign-Up Due</p></b><br><p style="color:blue;font-size:100%;">Chapter 16 Prelecture Due</p><br><p style="color:blue;font-size:100%;">Bonus Survey 4 Due</p></td>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">06</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">07</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">08</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">09</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">10</p></td>
# </tr>
# <tr>
#   <td><b>Week 12: Exam Week</b></td>
#   <td></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 15 Due</p></td>
#   <td><b><p style="color:red;font-size:120%;">Exam 3 at 7pm</p></b><br><p style="color:blue;font-size:100%;">Chapter 17 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 16 Due</p></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 18 Prelecture Due</p></td>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">13</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">14</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">15</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">16</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">17</p></td>
# </tr>
# <tr>
#   <td><b>Week 13: Chapters 17-19</b><br>(Sampling & Inference)</td>
#   <td></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 17 Due</p></td>
#   <td></td>
#   <td></td>
#   <td></td>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">20</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">21</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">22</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">23</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">24</p></td>
# </tr>
# <tr>
#   <td><b>Week 14: Chapters 20-22</b><br>(Hypothesis Testing: Z & t Tests)</td>
#   <td></td>
#   <td></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 20 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 18 Due</p></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 21 Prelecture Due</p></td>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">27</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">28</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">29</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">30</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">01</p></td>
# </tr>
# <tr>
#   <td><b>Week 15: Chapters 22-24</b><br>(Hypothesis Testing: Chi Square Tests)</td>
#   <td></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 19 Due</p></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 22 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 20 Due</p></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 23 Part 1 Prelecture Due</p></td>
# </tr>
# </table>
#
# <h3 style="text-align: center;">May</h3>
# <div class="heading-underline"></div>
# <table class="table table-bordered">
# <tr>
#   <th>Week</th>
#   <th>Mon</th>
#   <th>Tues</th>
#   <th>Wed</th>
#   <th>Thurs</th>
#   <th>Fri</th>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">04</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">05</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">06</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">07</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">08</p></td>
# </tr>
# <tr>
#   <td><b>Week 16: Last Week of Class</b><br>(Final Exam Review)</td>
#   <td></td>
#   <td><p style="color:blue;font-size:100%;">Chapter 23 Part 2 Prelecture Due</p></td>
#   <td><p style="color:red;font-size:100%;">HW Assignment 21 Due</p><br><p style="color:blue;font-size:100%;">Bonus Survey 5 Due</p></td>
#   <td><p><b>Reading Day</b><br>No Class :)</p></td>
#   <td><p>No Class :)</p></td>
# </tr>
# <tr>
#   <td style="line-height:1px;margin:0;"></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">11</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">12</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">13</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">14</p></td>
#   <td><p style="font-size:95%;line-height:1px;margin:0;text-align:center;">15</p></td>
# </tr>
# <tr>
#   <td><b>Week 17: Finals Week</b></td>
#   <td><b><p style="color:red;font-size:120%;">L1 (In Person Class) Final from 1:30pm-4:30pm</p></b></td>
#   <td><b><p style="color:red;font-size:120%;">KF: (Karle's Online Class) Final from: 8am-11am</p></b></td>
#   <td></td>
#   <td><b><p style="color:red;font-size:120%;">ONL (Albert's Online Class) Final from: 7pm-10pm</p></b></td>
#   <td><p><b>SUMMER BREAK!!!</b><br><br>Have a wonderful break!</p></td>
# </tr>
# </table>
#
# </div>

# %%
# pyperclip is needed for easier copy to clipboard
# pip install pyperclip
import pyperclip
pyperclip.copy(doc)
